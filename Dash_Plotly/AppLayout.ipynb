# %%
# !pip install dash

# %%
# !pip install dash_bootstrap_components
# Out:
# Collecting dash_bootstrap_components
#   Downloading dash_bootstrap_components-1.2.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: dash>=2.0.0 in c:\users\krish\anaconda3\lib\site-packages (from dash_bootstrap_components) (2.6.2)
# Requirement already satisfied: flask-compress in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.13)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\krish\anaconda3\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\krish\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\krish\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\krish\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\krish\anaconda3\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (8.0.4)
# Requirement already satisfied: colorama in c:\users\krish\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\krish\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.0.1)
# Requirement already satisfied: six in c:\users\krish\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\krish\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (8.0.1)
# Requirement already satisfied: brotli in c:\users\krish\anaconda3\lib\site-packages (from flask-compress->dash>=2.0.0->dash_bootstrap_components) (1.0.9)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-1.2.1

# %%
import dash
from dash import Dash, dcc, html
import dash_bootstrap_components as dbc
import plotly.express as px

# Instantiate our App and incorporate BOOTSTRAP theme stylesheet
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Incorporate data into App
df = px.data.gapminder()
print(df.head())

# Build the scatter plot
fig = px.scatter(data_frame=df, x="gdpPercap", y="lifeExp", size="pop",
                 color="continent", hover_name="country", log_x=True,
                 size_max=60, range_y=[30, 90], animation_frame='year')

# Build the layout to define what will be displayed on the page
app.layout = dbc.Container([
    dbc.Row([
        dbc.Col([
            html.H1("Life Expectancy vs. GDP", style={'textAlign': 'center'})
        ], width=12)
    ]),

    dbc.Row([
        dbc.Col([
            dcc.Graph(id='our-plot', figure=fig)
        ], width=12)
    ])
])


# callback is used to create app interactivity
#@callback()

# Run the App
if __name__ == '__main__':
    app.run_server()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_6_2m1666719111.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/deps/react@16.v2_6_2m1666719111.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_6_2m1666719111.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_6_2m1666719111.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v1_2_1m1666719192.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_6_2m1666719110.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_6_2m1666719111.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_6_2m1666719111.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_5m1666719112.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:42] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_6m1666719111.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:43] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:43] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:43] "GET /_favicon.ico?v=2.6.2 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:43] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2022 23:04:43] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]
